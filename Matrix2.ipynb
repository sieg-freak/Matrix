# %% [markdown]
# Погрузитесь в захватывающий мир будущего с нашей интерактивной историей 'Останки времени'. В 2287 году человечество раскинуло свои поселения по всей галактике, но с этим прогрессом пришли и новые загадки прошлого. Следуйте за археологом Элиасом Джексоном в его увлекательное путешествие через галактику, где ему предстоит разгадать тайны древних цивилизаций, бороться с загадочными существами и противостоять силам, желающим использовать древние технологии в своих эгоистичных целях.

# %%
import random

# Функция для первого акта
# При выборе 1 или 2 следует в Act_2()
# При выборе 3 активирует шорткад 
# Нужен чтобы гарантированно пройти в pills() конец истории 
def Act_1():
    
    print(
        "Год 2287. Человечество пробудило свои глаза к звездам, раскинув свои поселения по всему Солнечному Системе.\n"
        "Но с этим прогрессом пришли и новые вызовы.\n"
        "На вечеринке в роскошном космическом замке, висящем над планетой Марс, Элиас Джексон, знаменитый археолог, приветствовалгостей.\n"
        "В этом таинственном вечернем сиянии, его взгляд упал на таинственную женщину в красном платье, стоявшую в углу.\n"
        "Она казалась невидимой, но её присутствие было ощутимо в каждом уголке зала.\n")
    # Выбор действия игрока
    choice = input("Что вы предпримете?\n"
                   "1. Подойти к женщине и попробовать с ней поговорить.\n"
                   "2. Продолжить кружить по залу и наблюдать за ней издалека.\n"
                   "3. Игнорировать её и обратить внимание на других гостей.\n"
                   "Выберите действие: ")
    
    if choice == '1':
        
        print(
            '\nВы приближаетесь к женщине и спрашиваете: "Почему такая милая леди как вы, стоите в этом одиноком углу?"\n'
            'Совсем одна, готов поспорить, что к тебе никто не придет сегодня. Но тебе повезло встретить меня. Могу я составить компанию?\n')
        
        return Act_2() # Переход к следующему акту
    
    elif choice == '2':
        
        print(
            "\nВы решаете не привлекать лишнего внимания и остаться на месте, наблюдая за таинственной женщиной издалека.\n"
            "Внезапно, вы видите, как она что-то кладет в карман платья и направляется к выходу\n")
        
        return Act_2()
        
    elif choice == '3':
        
        print("\nВы решаете проигнорировать таинственную женщину и обратить внимание на других гостей на вечеринке.\n"
              "Но вдруг из другого конца зала разбиваются окна. Раздается шум, гости в панике пытаются найти выход.\n"
              "Девушка уже встала и направляется к заднему выходу, и, когда она выходит наружу.\n"
              "Вы видите, как группа людей в черном подходит к вам, и вы понимаете, что ваша жизнь в опасности.\n"
              "Безжалостные агенты захватывают вас и ведут в неизвестном направлении...\n")
        
        print("Дальше...")
        
        print("\033[34mСимуляция завершена\033[0m") # Конвертация текста в красный цвет
        return start() # Возвращение к началу игры

    else:
        print("Пожалуйста, введите корректный вариант.")
        
        return Act_1()
        
# Начало Цикла
# Все функции перетекают в start()
def start():
    print('\nВы тут же просыпаетесь от сна, тело дрожит от чувства падения и вы на полу. "Боже снова кошмар приснился"\n'
          'Вы встаете сначала умываетесь, и собираетесь пойти на работу, но перед этим проверяете почту. Вы замечаете книгу\n'
          'надпись "Симулякры и Симуляция" - тут же вы реагируете "Надо бы мне поменьше читать постмодернисткой ерунды".\n'
          '--New message: следуй за белым кроликом-- "Интересно я уже это где-то это слышал"')
    f = input("Как всегда твой рутинный день заканчивается.\n Задумутся о сообщении / или Пойти поспать\n Введите: Да / Нет      ").lower()
    
    if f == "нет":
        print("\nНа следуйщии день у тебя корпоратив, так что сегодня надо лечь по раньше\n"
              "\n----Переход----\n"
              "Вот ты уже на корпоративе, рядом с тобой сидит твой давний друг\n"
              "Ты рассказываешь ему про твой сон\n"
              '\n--"Что за чушь, чувак? Звучит как очередной роман про влюбленных написанный искусственным интелектом."\n'
              '\nМысли: интересно как он узнал. Возможно, что тут ...')
        
        input("Обратить внимание / не обращать      ")
        
        print("При следующем разговоре вы понимаете, что он не человек... 'Мысль прерываете со словами'\n"
              "\n\n __Мистер Андерсон!__")
        
        return start()
              
        
    elif f == "да":
        print("Перед сном вы задумываетесь о том сообщении, его вам прислал некий 'Морфиус'\n"
              "Хотел бы я знать, что значит этот кролик\n"
              "На этой мысли вы засыпаете\n"
              "\nВам снится тот же сон\n")
        return pills()

    else:
        return start()

# Функция для второго акта    
# С использрванием рандома
# Тут добавляется разветвление Side()
# Котрое перетекает в сегмент с загадкой
def Act_2():
    
    print('Женщина взглядывает на вас с удивлением, но затем улыбается.\n'
          '"Вы ищете ответы, верно?"- говорит она, протягивая вам небольшой диск. "Это изменит всё.\n'
          'Найдите меня, если захотите узнать больше", - произносит она и исчезает в толпе."')

    # используем рандом для определения исхода
    input("Придется бросить кости:     ").lower()

    roll = random.randint(1, 20)
    
    # Если больше или равно 10 алгоритм продалжается 
    if roll >= 10:
        
        print("\n\n\033[92mВы бросаете кость D20 и получаете результат:", roll, "\033[0m\n\n")

        print('\nВы решаете следовать за таинственной женщиной, надеясь раскрыть её секреты.\n'
              'Она выходит из зала и направляется к одной из удаленных площадок на крыше замка.\n'
              'Вы осторожно следуете за ней, стараясь не привлекать внимания.\n'
              'По прибытии на крышу вы видите, как она останавливается перед маленьким космическим кораблем, припаркованным у края.\n'
              'Она поворачивается и встречает ваш взгляд.\n'
              '\n"Я знала, что вы последуете за мной", - говорит она с улыбкой, предлагая вам войти в корабль.\n'
              '"Если вы действительно хотите узнать правду, то это ваш единственный шанс".\n')
        
        input('Другого выхода нет\n'
              'Пройти с ней?:  ') # Действие чтобы разделить сцену
        
        print('\nВы решаете принять предложение таинственной женщины и входите в космический корабль.\n'
              'Надписть над входом ---Навуходоносор---\n'
              'Двери закрываются за вами, и вы чувствуете, как корабль начинает подниматься в воздух.\n'
              '\nВнутри корабля женщина представляется как Лира, и говорит: "Меня отправили, чтобы\n'
              'Найти того, кто достоин найти истину. Вы - Элиас Джексон, археолог, который не боится рисковать.\n'
              'Мы отправимся в путешествие сквозь галактику, чтобы раскрыть тайны, которые многие считали утраченными в веках".\n'
              '\nОна вручает вам диск и продолжает: "Этот диск содержит информацию, которая может изменить ход истории.\n'
              'Найдите ключ и откройте дверь в новую эру для человечества".')

        a = input("1. Исследовать диск и попытаться понять его содержание.\n"
                  "2. Поговорить с Лирой, чтобы узнать больше о цели этого путешествия.\n"
                  "Выберите действие:   ")
        
        if a == '1':
            print("\nТы внимательно смотришь на нее, твое внимае привлекает ее тату\n"
                  "Где-то я уже видел это тату с белым кроликом\n")
            
            return side()
        
        elif a == '2':
            
            print('\n"Эй погодь, откуда ты меня знаешь?", Тут она показывает свой оригинальный образ,\n'
                  'На самом деле это не девушка, и он представляется "Привет меня Сайфер, извини что немного шокировал\n'
                  'Его перевоплащение никак вас не аффекти, Вас больше привлекает его тату с белым кроликом\n'
                  'Вы выдаете фразу "Хех, забавно меня это никак не удивляет но я где-то уже видел твое тату с кроликом,\n'
                  'Словно чувство дежавю", Сайфер вас тут же прерывает "Что ты сказал?"\n'
                  '"Дежавю, что тут не понятного". В мгновение вы теряете сознание и ...')
            
            return start()
        
        else:
            print("Пожалуйста, выберите корректное действие.")
            
            return Act_2()
    # Если меньше 10 то алгоритм заканчивается
    elif roll < 10:
        
        print("\n\n\033[91mВы бросаете кость D20 и получаете результат:", roll, "\033[0m\n\n")
        
        print("Вы видите, как группа людей в черном подходит к вам, и вы понимаете, что ваша жизнь в опасности.\n"
          "Безжалостные агенты захватывают вас и ведут в неизвестном направлении...\n")
        
        print("\033[34mСимуляция завершена\033[0m")


# Разветвление Side()
def side():
    print(" \nВы обсматриваете диск со всех сторон\n"
          "Вас изумляет его чистейщая красота.")
    while True:
        inspection = input("1 - Осмотреть надпись на чехле\n"
                           "2 - Осмотр закончен: ")
        
        # При выборе 1 алгоритм повторяется 
        if inspection == "1":
            print("\nНадпись удивляет проработкой.\n"
                  "Мечтают ли андроиды об электроовцах?\n" 
                  '"Интересно что это могла бы значить"\n') #Название известной книги
            return side() 

        elif inspection == "2":
            print("\nВы открываете диск \n"
                  "\n__Неожиданно!__\n\n Вас поглощает содержимое носителя\n"
                  "Вы призносите Шумы '______'\n"
                  "В мозг проникает вредоностное ПО\n"
                  "Вы видете свою внутренную оболочку\n"
                  "Везде надпись --SHODAN--\n" 
                  "К вам кто-то обращается\n") #Вирус в игре System Shock
            input("Продолжить: ")

            return side_2()
        else:
            return side()

# Сегмент с загадкой 
# Нужно отгадать сколько символов в тексте
def side_2():
    print("Приветствую мой маленький человечик\n"
          "Я пробралась в твой исодный код чтобы продолжить тебе придется ответить на пару моих загадок\n"
          "Давай начнем с простого\n"
          "\nПораженный страхом и могуществом --SHODAN-- ты не можешь выдать ни единой реакций")
    input("Ты бросаешь кости D20: ")
        
    text = 'Навуходоноср'
    count_o = text.count('о')

    roll = random.randint(1, 20)

    if roll < 10:
        
        print("\n\n\033[91mВы бросаете кость D20 и получаете результат:", roll, "\033[0m\n\n")

        ans = int(input("text = 'Навуходоноср'\ncount_o = text.count('о')\nответ:    "))
        
        if ans == count_o:
            print("Правильно!\nНо на этом мы не прощаемся \n\n\033[91mМИСТЕР АНДЕРСОН!!!\033[0m")
        
            return start()
        else:
            print("Неправильно!\n Удачи Мистер Андерсон! АХАХАХАХАХ")
        
            return start()
    # Дает подсказку если больше или равно 10 
    elif roll >= 10:
        
        print("\n\n\033[92mВы бросаете кость D20 и получаете результат:", roll, "\033[0m\n\n")
        
        ans = int(input("подсказка - сколько символо 'о' в тексте\ntext = 'Навуходоноср'\ncount_o = text.count('о')\nответ:    "))
        
        if ans == count_o:
            print("Правильно!\nНо на этом мы не прощаемся \n\n\033[91mМИСТЕР АНДЕРСОН!!!\033[0m")
        
            return start()
        else:
            print("Неправильно!\n Удачи Мистер Андерсон! АХАХАХАХАХ")
        
            return start()
# Заеершение истории 
def pills():
    print("Во сне ты принимаешь облик Нео из фильма 'Матрица' происходит культовая сцена 'Встреча с Морфиусом'\n"
          '\nМорфеус: Наконец-то. Добро пожаловать. Как ты уже понял, я - Морфеус.\n'
          'Нео: Это честь для меня.\n'
          'Морфеус: Нет, честь для меня. Пожалуйста, проходи, садись. Догадываюсь, сейчас ты чувствуешь себя Алисой, падающей в кроличью нору...\n'
          "Нео: Вроде того.\n"
          "Морфеус: Это читается в твоих глазах. Ты похож на человека, который ничему не удивляется, считая происходящее сном и веря, что вот-вот проснется...\n"
          "Морфеус: Ты веришь в Судьбу, Нео?\n"
          "Нео: Нет.\n"
          "Морфеус: Почему?\n"
          "Нео: Неприятно думать, что тобой манипулируют.\n"
          "Морфеус: Объясню, почему ты здесь. Потому, что ты что-то понял. Ты не можешь выразить это, но ощущаешь.\n"
          "Ты всю жизнь ощущал, что мир не в порядке - странная мысль, но ее не отогнать. Она - как заноза в мозгу.\n" 
          "Она сводит с ума. Не дает покоя. Это и привело тебя ко мне. Понимаешь, о чем я говорю?\n"
          "Нео: О Матрице?\n"
          "Морфеус: Ты хочешь узнать, что это? Матрица повсюду. Она окружает нас. Даже сейчас она с нами рядом.\n"
          "Ты видишь ее, когда смотришь в окно или включаешь телевизор. Ты ощущаешь ее, когда работаешь, идешь в церковь,\n"
          "когда платишь налоги. Целый мирок, надвинутый на глаза, чтобы спрятать правду.\n"
          "Нео: Какую?\n"
          "Морфеус: Что ты только раб, Нео. Как и все, ты с рождения в цепях. С рождения в тюрьме, которой не почуешь и не коснешься.\n"
          "В темнице для разума. Увы, невозможно объяснить, что такое Матрица... Ты должен увидеть это сам. Не поздно отказаться.\n"
          "Потом пути назад не будет.\n")
    
    print("\n\033[34m1. Примешь синюю таблетку - и сказке конец. Ты проснешься в своей постели и поверишь, что это был сон.\033[0m\n"
          "\033[91m2. Примешь красную таблетку - войдешь в страну чудес. Я покажу тебе, глубока ли кроличья нора.\033[0m\n"
          "Помни, я лишь предлагаю узнать правду, больше ничего.\n")
    
    r = input("Какую примешь Нео: 1 или 2      ")
    
    if r == "1":
        
        return start()
        
    elif r == "2": 
        
        print("Ты просыпаесшя на корабле Навуходоноср\n"
              "Морфеус: Добро пожаловать в реальный мир... Мы сделали это, Тринити. Мы нашли его.")
        print("\n На этой история заканчивается, продолжение смотрите в фильме --'The Matrix'--")
        
    else:
        return pills()
    

def main():
    
    while True:
        Act_1()
        choice = input("\n \n Хотите ли вы перезагрузить матрицу (да/нет): "
                      ).lower()
        
        if choice != 'да':
            print("\033[34mСимуляция завершена\033[0m")
                 
            break


if __name__ == "__main__":
    main()
# Out:
# Год 2287. Человечество пробудило свои глаза к звездам, раскинув свои поселения по всему Солнечному Системе.
# Но с этим прогрессом пришли и новые вызовы.
# На вечеринке в роскошном космическом замке, висящем над планетой Марс, Элиас Джексон, знаменитый археолог, приветствовалгостей.
# В этом таинственном вечернем сиянии, его взгляд упал на таинственную женщину в красном платье, стоявшую в углу.
# Она казалась невидимой, но её присутствие было ощутимо в каждом уголке зала.
